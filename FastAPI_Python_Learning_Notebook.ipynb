# %% [markdown]
# # FastAPI + Python Complete Learning Notebook
# This notebook contains notes, practice problems, and Fortune-50 level interview questions.

# %% [markdown]
# ## Section 1: Introduction to FastAPI
# FastAPI is a modern, fast web framework for building APIs with Python.
# - High performance (built on ASGI + Starlette)
# - Automatic docs (Swagger, Redoc)
# - Type hints → validation
# - Async support

# %%
# !pip install fastapi uvicorn nest_asyncio pyngrok
# Out:
# Collecting fastapi
#   Downloading fastapi-0.124.0-py3-none-any.whl.metadata (30 kB)
# Collecting uvicorn
#   Using cached uvicorn-0.38.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: nest_asyncio in c:\users\probi\python_example_project\python_basics\.vbasic\lib\site-packages (1.6.0)
# Collecting pyngrok
#   Downloading pyngrok-7.5.0-py3-none-any.whl.metadata (8.1 kB)
# Collecting starlette<0.51.0,>=0.40.0 (from fastapi)
#   Using cached starlette-0.50.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 (from fastapi)
#   Using cached pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\probi\python_example_project\python_basics\.vbasic\lib\site-packages (from fastapi) (4.15.0)
# Collecting annotated-doc>=0.0.2 (from fastapi)
#   Downloading annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Collecting annotated-types>=0.6.0 (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.5 (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi)
#   Using cached pydantic_core-2.41.5-cp313-cp313-win_amd64.whl.metadata (7.4 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi)
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: anyio<5,>=3.6.2 in c:\users\probi\python_example_project\python_basics\.vbasic\lib\site-packages (from starlette<0.51.0,>=0.40.0->fastapi) (4.11.0)
# Requirement already satisfied: idna>=2.8 in c:\users\probi\python_example_project\python_basics\.vbasic\lib\site-packages (from anyio<5,>=3.6.2->starlette<0.51.0,>=0.40.0->fastapi) (3.11)
# Requirement already satisfied: sniffio>=1.1 in c:\users\probi\python_example_project\python_basics\.vbasic\lib\site-packages (from anyio<5,>=3.6.2->starlette<0.51.0,>=0.40.0->fastapi) (1.3.1)
# Collecting click>=7.0 (from uvicorn)
#   Using cached click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: h11>=0.8 in c:\users\probi\python_example_project\python_basics\.vbasic\lib\site-packages (from uvicorn) (0.16.0)
# Requirement already satisfied: PyYAML>=5.1 in c:\users\probi\python_example_project\python_basics\.vbasic\lib\site-packages (from pyngrok) (6.0.3)
# Requirement already satisfied: colorama in c:\users\probi\python_example_project\python_basics\.vbasic\lib\site-packages (from click>=7.0->uvicorn) (0.4.6)
# Downloading fastapi-0.124.0-py3-none-any.whl (112 kB)
# Using cached pydantic-2.12.5-py3-none-any.whl (463 kB)
# Using cached pydantic_core-2.41.5-cp313-cp313-win_amd64.whl (2.0 MB)
# Using cached starlette-0.50.0-py3-none-any.whl (74 kB)
# Using cached uvicorn-0.38.0-py3-none-any.whl (68 kB)
# Downloading pyngrok-7.5.0-py3-none-any.whl (24 kB)
# Downloading annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached click-8.3.1-py3-none-any.whl (108 kB)
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Installing collected packages: typing-inspection, pyngrok, pydantic-core, click, annotated-types, annotated-doc, uvicorn, starlette, pydantic, fastapi
#
#    ---- -----------------------------------  1/10 [pyngrok]
#    ---- -----------------------------------  1/10 [pyngrok]
#    ---- -----------------------------------  1/10 [pyngrok]
#    ---- -----------------------------------  1/10 [pyngrok]
#    ---- -----------------------------------  1/10 [pyngrok]
#    -------- -------------------------------  2/10 [pydantic-core]
#    ------------ ---------------------------  3/10 [click]
#    ------------ ---------------------------  3/10 [click]
#    ------------ ---------------------------  3/10 [click]
#    ------------ ---------------------------  3/10 [click]
#    ---------------- -----------------------  4/10 [annotated-types]
#    ------------------------ ---------------  6/10 [uvicorn]
#    ------------------------ ---------------  6/10 [uvicorn]
#    ------------------------ ---------------  6/10 [uvicorn]
#    ------------------------ ---------------  6/10 [uvicorn]
#    ------------------------ ---------------  6/10 [uvicorn]
#    ------------------------ ---------------  6/10 [uvicorn]
#    ------------------------ ---------------  6/10 [uvicorn]
#    ------------------------ ---------------  6/10 [uvicorn]
#    ------------------------ ---------------  6/10 [uvicorn]
#    ---------------------------- -----------  7/10 [starlette]
#    ---------------------------- -----------  7/10 [starlette]
#    ---------------------------- -----------  7/10 [starlette]
#    ---------------------------- -----------  7/10 [starlette]
#    ---------------------------- -----------  7/10 [starlette]
#    ---------------------------- -----------  7/10 [starlette]
#    ---------------------------- -----------  7/10 [starlette]
#    ---------------------------- -----------  7/10 [starlette]
#    -------------------------------- -------  8/10 [pydantic]
#    -------------------------------- -------  8/10 [pydantic]
#    -------------------------------- -------  8/10 [pydantic]
#    -------------------------------- -------  8/10 [pydantic]
#    -------------------------------- -------  8/10 [pydantic]
#    -------------------------------- -------  8/10 [pydantic]
#    -------------------------------- -------  8/10 [pydantic]
#    -------------------------------- -------  8/10 [pydantic]
#    -------------------------------- -------  8/10 [pydantic]
#    -------------------------------- -------  8/10 [pydantic]
#    -------------------------------- -------  8/10 [pydantic]
#    -------------------------------- -------  8/10 [pydantic]
#    -------------------------------- -------  8/10 [pydantic]
#    -------------------------------- -------  8/10 [pydantic]
#    -------------------------------- -------  8/10 [pydantic]
#    -------------------------------- -------  8/10 [pydantic]
#    -------------------------------- -------  8/10 [pydantic]
#    -------------------------------- -------  8/10 [pydantic]
#    -------------------------------- -------  8/10 [pydantic]
#    -------------------------------- -------  8/10 [pydantic]
#    -------------------------------- -------  8/10 [pydantic]
#    -------------------------------- -------  8/10 [pydantic]
#    ------------------------------------ ---  9/10 [fastapi]
#    ------------------------------------ ---  9/10 [fastapi]
#    ------------------------------------ ---  9/10 [fastapi]
#    ------------------------------------ ---  9/10 [fastapi]
#    ------------------------------------ ---  9/10 [fastapi]
#    ------------------------------------ ---  9/10 [fastapi]
#    ------------------------------------ ---  9/10 [fastapi]
#    ------------------------------------ ---  9/10 [fastapi]
#    ------------------------------------ ---  9/10 [fastapi]
#    ------------------------------------ ---  9/10 [fastapi]
#    ------------------------------------ ---  9/10 [fastapi]
#    ---------------------------------------- 10/10 [fastapi]
#
# Successfully installed annotated-doc-0.0.4 annotated-types-0.7.0 click-8.3.1 fastapi-0.124.0 pydantic-2.12.5 pydantic-core-2.41.5 pyngrok-7.5.0 starlette-0.50.0 typing-inspection-0.4.2 uvicorn-0.38.0

# %%
from fastapi import FastAPI
import nest_asyncio, uvicorn

nest_asyncio.apply()

app = FastAPI()

@app.get("/")
def home():
    return {"msg": "Hello from FastAPI Notebook!"}

# %% [markdown]
# ## Practice Problem 1
# Create an API `/square/{num}` that returns the square of a number.

# %%
@app.get("/square/{num}")
def square(num: int):
    return {"result": num*num}

# %% [markdown]
# ## Fortune 50 Interview Questions
# 1. Explain ASGI vs WSGI.
# 2. How does FastAPI handle dependency injection?
# 3. Explain Pydantic validation flow.
# 4. Difference between sync/async in FastAPI.
# 5. How would you scale FastAPI in production?
